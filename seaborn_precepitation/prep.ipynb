# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rain_data=pd.read_csv('average_precipitation.csv')

# %%
rain_data
# Out:
#     Year  Average Precipitation (mm)
# 0   2001                     2251.50
# 1   2002                     2285.70
# 2   2003                     2139.90
# 3   2004                     2210.38
# 4   2005                     1980.05
# 5   2006                     1880.04
# 6   2007                     2432.20
# 7   2008                     2143.17
# 8   2009                     1945.63
# 9   2010                     2195.64
# 10  2011                     1932.64
# 11  2012                     1941.19
# 12  2013                     1984.83
# 13  2014                     1767.21
# 14  2015                     2472.81
# 15  2016                     2067.81
# 16  2017                     2664.20
# 17  2018                     1763.89
# 18  2019                     1979.05
# 19  2020                     2423.84
# 20  2021                     2075.34

# %% [markdown]
# # 1. Bar Plot – Comparing precipitation across years:
# 2. Use: When comparing quantities across categories.
# Best for: Discrete data, especially categorical data (e.g., sales by region, counts of events).
# Example: Comparing average precipitation across different years or months.
# Explanation: Bar plots are ideal for comparing a single numeric value (like average) across different categories (like different years or regions).
# When to Use:
#
# When you have categorical data and want to compare individual category values.
# For datasets where categories have no inherent ordering (like regions or product types).

# %%
plt.figure(figsize=(14, 7))
sns.barplot(
    x='Year', 
    y='Average Precipitation (mm)', 
    data=rain_data, 
    palette="coolwarm",  # Custom color palette
)
plt.xticks(rotation=45, fontsize=10)  # Rotate x-axis labels for better readability
plt.title("Average Precipitation per Year (2001–2021)", fontsize=16, weight='bold')  # Add title
plt.xlabel("Year", fontsize=12, weight='bold')  # Add x-axis label
plt.ylabel("Average Precipitation (mm)", fontsize=12, weight='bold')  # Add y-axis label
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add gridlines for clarity
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13572\3872960691.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
rain_data
# Out:
#     Year  Average Precipitation (mm)
# 0   2001                     2251.50
# 1   2002                     2285.70
# 2   2003                     2139.90
# 3   2004                     2210.38
# 4   2005                     1980.05
# 5   2006                     1880.04
# 6   2007                     2432.20
# 7   2008                     2143.17
# 8   2009                     1945.63
# 9   2010                     2195.64
# 10  2011                     1932.64
# 11  2012                     1941.19
# 12  2013                     1984.83
# 13  2014                     1767.21
# 14  2015                     2472.81
# 15  2016                     2067.81
# 16  2017                     2664.20
# 17  2018                     1763.89
# 18  2019                     1979.05
# 19  2020                     2423.84
# 20  2021                     2075.34

# %% [markdown]
# # 2. Line Plot – Showing the trend of precipitation over years:
# 3. 2. Line Plot
# Use: To show trends over time or continuous data.
# Best for: Time-series data or any data that follows a continuous pattern.
# Example: Showing the trend of precipitation over the years.
# Explanation: Line plots show the relationship between two continuous variables and are especially good at showing trends and changes over time.
# When to Use:
#
# When you want to visualize data over time or show trends.
# When the data points are ordered (like time or sequential measurements

# %%
plt.figure(figsize=(14, 7))  # Set figure size for better readability
sns.lineplot(x='Year', y='Average Precipitation (mm)', data=rain_data, marker='o', color='b', linestyle='-', linewidth=2)
plt.xticks(rotation=45, fontsize=10)  # Rotate x-axis labels for better readability
plt.title("Yearly Average Precipitation (2001–2021)", fontsize=16, weight='bold')  # Add title
plt.xlabel("Year", fontsize=12, weight='bold')  # Add x-axis label
plt.ylabel("Average Precipitation (mm)", fontsize=12, weight='bold')  # Add y-axis label
plt.grid(True, linestyle='--', alpha=0.7)  # Add gridlines for clarity
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
rain_data
# Out:
#     Year  Average Precipitation (mm)
# 0   2001                     2251.50
# 1   2002                     2285.70
# 2   2003                     2139.90
# 3   2004                     2210.38
# 4   2005                     1980.05
# 5   2006                     1880.04
# 6   2007                     2432.20
# 7   2008                     2143.17
# 8   2009                     1945.63
# 9   2010                     2195.64
# 10  2011                     1932.64
# 11  2012                     1941.19
# 12  2013                     1984.83
# 13  2014                     1767.21
# 14  2015                     2472.81
# 15  2016                     2067.81
# 16  2017                     2664.20
# 17  2018                     1763.89
# 18  2019                     1979.05
# 19  2020                     2423.84
# 20  2021                     2075.34

# %%
x=rain_data['Year']

# %%
y=rain_data['Average Precipitation (mm)']

# %% [markdown]
# **3. Scatter Plot – Showing the relationship between years and precipitation:

# %%
y = np.sin(x)

# Plot the sine wave
plt.figure(figsize=(10, 6))
plt.plot(x, y, label="sin(x)", color="b", linewidth=2)
plt.title("Sinusoidal Plot (sin(x))", fontsize=16, weight='bold')
plt.xlabel("X-axis (radians)", fontsize=12, weight='bold')
plt.ylabel("Amplitude", fontsize=12, weight='bold')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
x_sin = np.linspace(0, 2 * np.pi, len(rain_data))
y_sin = np.sin(x_sin)

# Set the style and color palette for the plot
sns.set_style("white")
sns.set_palette("husl")

# Create the plot
plt.figure(figsize=(14, 7))

# Plot precipitation data as bars
sns.barplot(x='Year', y='Average Precipitation (mm)', data=rain_data, color="skyblue", alpha=0.7)

# Overlay the sine wave
plt.plot(rain_data['Year'], y_sin * (max(rain_data['Average Precipitation (mm)']) - min(rain_data['Average Precipitation (mm)'])) + min(rain_data['Average Precipitation (mm)']),
         label="Sinusoidal Curve", color="red", linewidth=2)

# Titles and labels
plt.title("Average Precipitation with Sinusoidal Overlay", fontsize=16, weight='bold')
plt.xlabel("Year", fontsize=12, weight='bold')
plt.ylabel("Precipitation (mm)", fontsize=12, weight='bold')

# Grid and legend
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# # 4. Histogram
# Use: To show the distribution of a single variable.
# Best for: Understanding the distribution (normal, skewed, uniform) of a dataset.
# Example: Showing the distribution of precipitation values across years.
# Explanation: Histograms help to visualize how data is distributed by grouping values into bins and counting how many values fall within each bin.
# When to Use:
#
# When you need to understand the distribution of a variable.
# For showing frequency or count of values within certain ranges.

# %%
rain_data

# %%
sns.displot(rain_data)

# %%
sns.displot(rain_data['Average Precipitation (mm)'], kde=True, bins=10)

# Titles and labels
plt.title("Distribution of Average Precipitation", fontsize=16, weight='bold')
plt.xlabel("Precipitation (mm)", fontsize=12, weight='bold')
plt.ylabel("Frequency", fontsize=12, weight='bold')

plt.show()

# %% [markdown]
# # 5. Scatter Plot
# Use: To show relationships between two continuous variables.
# Best for: Identifying correlations and relationships between two variables.
# Example: Showing the relationship between temperature and precipitation.
# Explanation: Scatter plots are useful to identify whether a relationship exists between two variables and if that relationship is linear or nonlinear.
# When to Use:
#
# When you have two continuous variables and want to understand their correlation.
# To detect patterns, clusters, or outliers.

# %%
plt.figure(figsize=(14, 7))
sns.scatterplot(x='Year', y='Average Precipitation (mm)', data=rain_data, color="b", s=100)
plt.title("Year vs Average Precipitation", fontsize=16, weight='bold')
plt.xlabel("Year", fontsize=12, weight='bold')
plt.ylabel("Average Precipitation (mm)", fontsize=12, weight='bold')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Facet Grid / Subplot – Showing precipitation trends across different categories (if you had categorical data like regions or months):
# 10. Facet Grid / Subplot
# Use: To create multiple subplots based on a categorical variable.
# Best for: Comparing the same plot across different categories.
# Example: Comparing precipitation trends across different regions.
# Explanation: Facet grids allow you to create multiple plots, each corresponding to a subset of the data based on a categorical variable.
# When to Use:
#
# When you want to split a dataset by categories and show the same plot for each category.
# For comparing different segments or categories in your dataset.

# %%
# Adding a 'Region' column to the data for demonstration purposes
rain_data['Region'] = ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 
                       'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
                       'North', 'South', 'East', 'West', 'North']

# Plotting Facet Grid
g = sns.FacetGrid(rain_data, col="Region", height=4, aspect=1.5)
g.map(sns.lineplot, "Year", "Average Precipitation (mm)")
g.set_titles("{col_name} Region")
g.set_axis_labels("Year", "Precipitation (mm)")
g.tight_layout()
plt.show()

# %% [markdown]
# # 8. Violin Plot – Showing distribution and density of precipitation:
# 10. 9. Violin Plot
# Use: To show the distribution of a variable and its probability density.
# Best for: Visualizing distribution, probability density, and outliers.
# Example: Comparing precipitation distribution across different years.
# Explanation: Violin plots combine the features of box plots and density plots, showing the distribution and its density.
# When to Use:
#
# When you want to visualize the distribution of a continuous variable and compare it across categories or groups.
# To visualize multiple distributions and compare the spread and density.

# %%
new_data=rain_data.drop('Region',axis=1)

# %%
new_data

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='Year', y='Average Precipitation (mm)', data=rain_data)
plt.title("Violin Plot: Precipitation Distribution Across Years")
plt.xlabel("Year")
plt.ylabel("Precipitation (mm)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Pie Chart
# Use: To show proportions of a whole.
# Best for: Showing percentage breakdowns of categorical data.
# Example: Showing the proportion of precipitation in different months of the year.
# Explanation: Pie charts are used to show relative proportions and help highlight which categories make up a whole.
# When to Use:
#
# When you need to show proportions or relative percentages of a total.
# Best for small datasets with a few categories (e.g., market share by brand).

# %%
# Calculate the total precipitation
total_precipitation = rain_data['Average Precipitation (mm)'].sum()

# Calculate proportions for each year
rain_data['Proportion'] = rain_data['Average Precipitation (mm)'] / total_precipitation

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(rain_data['Proportion'], labels=rain_data['Year'], autopct='%1.1f%%', startangle=90)
plt.title("Proportion of Precipitation by Year")
plt.show()

# %% [markdown]
# 7. Heatmap – Showing the correlation between different columns (if you add more data columns):
# Since your data has just two columns, the heatmap would not be that useful here. However, if you had multiple variables, you could use it to show correlations.

# %%
new_data

# %% [markdown]
# # 10.Heatmap
#
# Use: To represent data in a matrix format where values are displayed using color gradients.
# Best for: Visualizing complex data matrices and identifying patterns.
# Example: Visualizing precipitation over time or across regions.
# Explanation: Heatmaps are useful when you have large datasets with multiple variables, making it easier to spot patterns or correlations.
# When to Use:
#
# When you have a matrix or large table of data and want to understand the relationships between multiple variables.
# To highlight patterns or concentrations in data

# %%
sns.heatmap(new_data.corr(),annot=True)

# %% [markdown]
# # 11.Pair Plot (Scatterplot Matrix)
# Use: To visualize relationships between multiple variables in a dataset.
# Best for: Exploring the relationships between multiple continuous variables.
# Example: Analyzing how precipitation relates to multiple other factors (like temperature and humidity).
# Explanation: A pair plot shows scatter plots for every pair of features in a dataset, allowing you to identify relationships and patterns between multiple variables at once.
# When to Use:
#
# When you want to visualize relationships between multiple continuous variables.
# To explore pairwise relationships in multivariate data.

# %%
# Use the extended dataset with multiple variables
sns.pairplot(new_data)
plt.suptitle("Pair Plot for Precipitation, Temperature, and Humidity", y=1.02)
plt.show()

# %%
rain_data

# %%
total_precipitation = new_data['Average Precipitation (mm)'].sum()

# Calculate proportions for each year
new_data['Proportion'] = new_data['Average Precipitation (mm)'] / total_precipitation

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(new_data['Proportion'], labels=new_data['Year'], autopct='%1.1f%%', startangle=90)
plt.title("Proportion of Precipitation by Year")
plt.show()

# %%
rain_data

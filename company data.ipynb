# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\User\Documents\Python data science\archive (1)\shopping_trends.csv')

# %% [markdown]
# # Adjust display settings to show all rows and columns
# pd.set_option('display.max_rows', None)  # Show all rows
#
#
# # Display the DataFrame
# display(data)

# %% [markdown]
# # Ensure all rows and columns are visible in Jupyter Notebook
# from IPython.display import display
#
# # Display all rows and columns
#
# pd.set_option('display.max_columns', None)
#
# display(data)

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
data.count()
# Out:
# Customer ID                 3900
# Age                         3900
# Gender                      3900
# Item Purchased              3900
# Category                    3900
# Purchase Amount (USD)       3900
# Location                    3900
# Size                        3900
# Color                       3900
# Season                      3900
# Review Rating               3900
# Subscription Status         3900
# Payment Method              3900
# Shipping Type               3900
# Discount Applied            3900
# Promo Code Used             3900
# Previous Purchases          3900
# Preferred Payment Method    3900
# Frequency of Purchases      3900
# dtype: int64

# %% [markdown]
# data['Discount Applied']

# %%
position = data.columns.get_loc('Discount Applied')

# %%
position
# Out:
# 14

# %%
ndata=data.drop(data.columns[14],axis=1)

# %%
ndata.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.describe(include='object')
# Out:
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
#        Subscription Status Payment Method  Shipping Type Discount Applied  \
# count                 3900           3900           3900             3900
# unique                   2              6              6                2
# top                     No    Credit Card  Free Shipping               No
# freq                  2847            696            675             2223
#
#        Promo Code Used Preferred Payment Method Frequency of Purchases
# count             3900                     3900                   3900
# unique               2                        6                      7
# ...

# %%
for col in data.describe(include='object').columns:
    print(col)
    print(data[col].unique())
    print('-'*50)
# Out:
# Gender
# ['Male' 'Female']
# --------------------------------------------------
# Item Purchased
# ['Blouse' 'Sweater' 'Jeans' 'Sandals' 'Sneakers' 'Shirt' 'Shorts' 'Coat'
#  'Handbag' 'Shoes' 'Dress' 'Skirt' 'Sunglasses' 'Pants' 'Jacket' 'Hoodie'
#  'Jewelry' 'T-shirt' 'Scarf' 'Hat' 'Socks' 'Backpack' 'Belt' 'Boots'
#  'Gloves']
# --------------------------------------------------
# Category
# ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
# --------------------------------------------------
# Location
# ['Kentucky' 'Maine' 'Massachusetts' 'Rhode Island' 'Oregon' 'Wyoming'
#  'Montana' 'Louisiana' 'West Virginia' 'Missouri' 'Arkansas' 'Hawaii'
#  'Delaware' 'New Hampshire' 'New York' 'Alabama' 'Mississippi'
#  'North Carolina' 'California' 'Oklahoma' 'Florida' 'Texas' 'Nevada'
#  'Kansas' 'Colorado' 'North Dakota' 'Illinois' 'Indiana' 'Arizona'
#  'Alaska' 'Tennessee' 'Ohio' 'New Jersey' 'Maryland' 'Vermont'
# ...

# %%
nposition=data.columns.get_loc('Season')

# %%
nposition
# Out:
# 9

# %%
ndata.shape
# Out:
# (3900, 18)

# %%
data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000
